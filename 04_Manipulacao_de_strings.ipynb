# %%
# Entrada do usuário
texto = input("Digite uma frase: ")

# Contagem de caracteres
print(f"Tamanho: {len(texto)} caracteres")

# Conversão para maiúsculas
print(f"Maiúsculas: {texto.upper()}")

# Conversão para minúsculas
print(f"Minúsculas: {texto.lower()}")

# Fatiamento
print(f"Primeiros 5 caracteres: {texto[:5]}")
print(f"Últimos 5 caracteres: {texto[-5:]}")
# Out:
# Digite uma frase:  Um dia Eu me tornarei rei
# Tamanho: 25 caracteres
# Maiúsculas: UM DIA EU ME TORNAREI REI
# Minúsculas: um dia eu me tornarei rei
# Primeiros 5 caracteres: Um di
# Últimos 5 caracteres: i rei
